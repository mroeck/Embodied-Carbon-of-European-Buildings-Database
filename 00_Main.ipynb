# %% [markdown]
# # Main script

# %% [markdown]
# Authors: [Andreas Sørensen](https://www.linkedin.com/in/a-soerensen) and [Martin Röck](https://www.linkedin.com/in/martinroeck/) - Source: https://doi.org/10.5281/zenodo.5895051

# %% [markdown]
# **Call scripts in sequence**

# %%
# SETUP
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gs
import seaborn as sns
import time

# %%
#Call data pre-processing scripts
# %run ./01_Preproc_DCT.ipynb
# %run ./01_Preproc_CLF.ipynb
# %run ./01_Preproc_CSTB.ipynb

#Call DataConcat script
# %run ./02_Data_Concat.ipynb

#Call FeatEng script
# %run ./03_Data_FeatEng.ipynb

#Call DataAnalysis script
# %run ./04_DataAnalysis_MainFigures.ipynb

print("Done")
# Out:
# Pre-processing DCT data...
# DCT data pre-processed.
# Pre-processing CLF data...
# CLF data pre-processed.
# Pre-processing CSTB data...
# CSTB data pre-processed.
# Concatenating pre-processed data from DCT, CSTB and CLF...
# Data from DCT, CSTB and CLF concatenated.
# Feature engineering data for analysis...
# Data has been feature engineered and ready for analysis.
# Analysing data and generating figures...
# Figures generated.
# Done
